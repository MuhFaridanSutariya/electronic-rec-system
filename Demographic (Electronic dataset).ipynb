# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv('data/df_electronics.csv')
df.head()
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %% [markdown]
# ## Data Engineering

# %%
df.shape
# Out:
# (1292954, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 10 columns):
# item_id       1292954 non-null int64
# user_id       1292954 non-null int64
# rating        1292954 non-null float64
# timestamp     1292954 non-null object
# model_attr    1292954 non-null object
# category      1292954 non-null object
# brand         331120 non-null object
# year          1292954 non-null int64
# user_attr     174124 non-null object
# split         1292954 non-null int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 98.6+ MB

# %%
df.describe()
# Out:
#             item_id       user_id        rating          year         split
# count  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06
# mean   4.183588e+03  5.605127e+05  4.051482e+00  2.012938e+03  1.747587e-01
# std    2.525346e+03  3.342374e+05  1.379732e+00  2.643513e+00  5.506810e-01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.999000e+03  0.000000e+00
# 25%    2.018000e+03  2.697482e+05  4.000000e+00  2.012000e+03  0.000000e+00
# 50%    3.930000e+03  5.518920e+05  5.000000e+00  2.014000e+03  0.000000e+00
# 75%    6.289000e+03  8.474858e+05  5.000000e+00  2.015000e+03  0.000000e+00
# max    9.559000e+03  1.157632e+06  5.000000e+00  2.018000e+03  2.000000e+00

# %%
df.isnull().sum()
# Out:
# item_id             0
# user_id             0
# rating              0
# timestamp           0
# model_attr          0
# category            0
# brand          961834
# year                0
# user_attr     1118830
# split               0
# dtype: int64

# %%
df['item_id'].value_counts().sort_values(ascending=False)
# Out:
# 7780    28530
# 2031     9393
# 1575     8622
# 2279     6278
# 2486     5810
#         ...
# 1529        1
# 4253        1
# 9559        1
# 7810        1
# 3972        1
# Name: item_id, Length: 9560, dtype: int64

# %% [markdown]
# ## Membuat kolom count dan mean dari sebuah rating

# %%
df1 = df.groupby('item_id')['rating'].agg(['count','mean'])
df1 = df1.sort_values('count', ascending=False)

# %%
df1.head()
# Out:
#          count      mean
# item_id
# 7780     28530  4.400911
# 2031      9393  4.418184
# 1575      8622  4.218743
# 2279      6278  4.168844
# 2486      5810  4.306368

# %% [markdown]
# ### menghapus kolom yang tidak berguna dan banyak missing valuenya. disini kita tidak menghapus kolom brand di karenakan kolom tersebut sangat penting

# %%
df.drop(columns=['timestamp', 'user_attr', 'split', 'model_attr'], inplace=True)

# %% [markdown]
# ### Menggabungkan kolom dari count dan mean kedalam dataframe awal kita

# %%
df = pd.concat([df, df1], join = 'outer', axis = 1).sort_values('count', ascending=False)
df.head(10)
# Out:
#       item_id  user_id  rating                 category    brand  year  \
# 7780      372     7509     4.0           Camera & Photo  Philips  2006
# 2031      119     1963     5.0  Computers & Accessories  Toshiba  2004
# 1575       73     1530     5.0           Camera & Photo    Canon  2002
# 2279      121     2203     3.0  Computers & Accessories  Linksys  2003
# 2486      145     2399     1.0           Camera & Photo    Canon  2004
# 2340       83     2258     5.0  Computers & Accessories  Linksys  2003
# 5795      300     5583     5.0  Computers & Accessories      NaN  2006
# 1715       93     1665     3.0           Camera & Photo     Sony  2003
# 1124        3     1103     1.0           Camera & Photo      NaN  2005
# 1886       39     1826     5.0           Camera & Photo     Sony  2001
#
#         count      mean
# 7780  28530.0  4.400911
# 2031   9393.0  4.418184
# 1575   8622.0  4.218743
# 2279   6278.0  4.168844
# 2486   5810.0  4.306368
# 2340   5790.0  4.625734
# 5795   5554.0  3.921318
# 1715   5482.0  4.797337
# 1124   5353.0  3.998879
# 1886   5323.0  4.109149

# %% [markdown]
# ## Phase 1 : Filtering

# %%
df['category'].unique()
# Out:
# array(['Camera & Photo', 'Computers & Accessories',
#        'Portable Audio & Video', 'Accessories & Supplies', 'Headphones',
#        'Television & Video', 'Home Audio', 'Car Electronics & GPS',
#        'Security & Surveillance', 'Wearable Technology'], dtype=object)

# %%
category = 'Computers & Accessories'
brand = 'Toshiba'
year = (2000, 2016)
topk = 10

# %%
filter_criteria = (df['category'] == category) & (df['brand'] == brand) & (df['year'].between(year[0], year[1]))

# %%
result = df[ filter_criteria ]
result.head()
# Out:
#       item_id  user_id  rating                 category    brand  year  \
# 2031      119     1963     5.0  Computers & Accessories  Toshiba  2004
# 2237      144     2163     5.0  Computers & Accessories  Toshiba  2004
# 679        44      668     5.0  Computers & Accessories  Toshiba  2001
# 2380      151     2199     5.0  Computers & Accessories  Toshiba  2006
# 2083      119     2012     5.0  Computers & Accessories  Toshiba  2004
#
#        count      mean
# 2031  9393.0  4.418184
# 2237  3777.0  4.368546
# 679    847.0  3.149941
# 2380   671.0  4.192250
# 2083   501.0  4.786427

# %% [markdown]
# ## Phase 2 : Scoring (Sudah kita lakukan diawal tadi yaitu count dan mean)

# %% [markdown]
# ## Phase 3 : Sorting

# %%
recommendation = result.sort_values("count", ascending=False).head(topk) 
recommendation
# Out:
#       item_id  user_id  rating                 category    brand  year  \
# 2031      119     1963     5.0  Computers & Accessories  Toshiba  2004
# 2237      144     2163     5.0  Computers & Accessories  Toshiba  2004
# 679        44      668     5.0  Computers & Accessories  Toshiba  2001
# 2380      151     2199     5.0  Computers & Accessories  Toshiba  2006
# 2083      119     2012     5.0  Computers & Accessories  Toshiba  2004
# 2085       44     2014     1.0  Computers & Accessories  Toshiba  2001
# 2138      125     2066     5.0  Computers & Accessories  Toshiba  2005
# 2019      119     1951     5.0  Computers & Accessories  Toshiba  2004
# 1839      119     1783     2.0  Computers & Accessories  Toshiba  2004
# 1176       44     1153     1.0  Computers & Accessories  Toshiba  2001
#
#        count      mean
# 2031  9393.0  4.418184
# 2237  3777.0  4.368546
# 679    847.0  3.149941
# 2380   671.0  4.192250
# 2083   501.0  4.786427
# 2085   489.0  4.351738
# 2138   357.0  3.817927
# 2019   321.0  4.473520
# 1839   262.0  4.030534
# 1176   124.0  3.411290

# %% [markdown]
# ### export dataframe yang telah di modifikasi ke sebuah file dengan ekstensi csv

# %%
csv_data = df.to_csv('electronics.csv', index =False)

# %% [markdown]
# ## ML engineering

# %%
class RecommenderSystem:
    def __init__(self, data):
        self.df = pd.read_csv(data)
    
    def recommend(self, category=None, brand=None, year=None, topk=10):
        df = self.df.copy()
        df = self.demographic_filter(df, category=category, brand=brand, year=year)
        
        result = df.sort_values("count", ascending=False)
        result = result.head(topk) 
        return result
    
    @staticmethod
    def demographic_filter(df, category=None, brand=None, year=None, topk=10):
        df = df.copy()
        
        if category is not None :
            df = df[(df['category'] == category)]
        if brand is not None :
            df = df[(df['brand'] == brand)]
        if year is not None :
            df = df[(df['year'].between(year[0], year[1]))]
        return df

# %%
recsys = RecommenderSystem(data='electronics.csv')

# %% [markdown]
# ## Berikut adalah hasil rekomendasi berdasarkan barang dengan pembeli terbanyak dan juga telah kita filter terlebih dahulu

# %%
recsys.recommend(category='Computers & Accessories', brand='Toshiba', year=(2000,2016))
# Out:
#       item_id  user_id  rating                 category    brand  year  \
# 1         119     1963     5.0  Computers & Accessories  Toshiba  2004
# 30        144     2163     5.0  Computers & Accessories  Toshiba  2004
# 283        44      668     5.0  Computers & Accessories  Toshiba  2001
# 375       151     2199     5.0  Computers & Accessories  Toshiba  2006
# 550       119     2012     5.0  Computers & Accessories  Toshiba  2004
# 565        44     2014     1.0  Computers & Accessories  Toshiba  2001
# 777       125     2066     5.0  Computers & Accessories  Toshiba  2005
# 864       119     1951     5.0  Computers & Accessories  Toshiba  2004
# 1034      119     1783     2.0  Computers & Accessories  Toshiba  2004
# 1914       44     1153     1.0  Computers & Accessories  Toshiba  2001
#
#        count      mean
# 1     9393.0  4.418184
# 30    3777.0  4.368546
# 283    847.0  3.149941
# 375    671.0  4.192250
# 550    501.0  4.786427
# 565    489.0  4.351738
# 777    357.0  3.817927
# 864    321.0  4.473520
# 1034   262.0  4.030534
# 1914   124.0  3.411290
